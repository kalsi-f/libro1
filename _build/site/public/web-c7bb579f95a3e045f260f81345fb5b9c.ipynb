# %% [markdown]
# # Libro en formato web con github pages

# %%
jupyter book init --gh-pages

# %% [markdown]
# :::{tip}
# Recordar que para ir actualizando la web es necesario hacer un build en conda powershell y hacer comit de ese build, además de los otros cambios que hayamos hecho, asi se actualizara el sitio web
# :::
