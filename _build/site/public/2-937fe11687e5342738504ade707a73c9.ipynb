# %% [markdown]
# # Jupyter Book

# %% [markdown]
# ## Instalación

# %%
conda install -c conda-forge jupyter-book

# %%
jupyter-book --versión

# %% [markdown]
# ### Librerias necesarias para confeccionar el libro

# %%
conda install python=3.11 matplotlib numpy pandas bokeh git

# %% [markdown]
# ### creamos una carpeta en el escritorio para nuestro libro

# %%
cd Desktop

# %%
mkdir libroEjemplo

# %%
cd libroEjemplo
