# %% [markdown]
# # 3. Libro en formato web con github pages

# %%
jupyter book init --gh-pages

# %% [markdown]
# :::{tip}
# Recordar que para ir actualizando la web es necesario hacer build, luego un commit con los cambios y el build, finalmente un ultimo build y veremos todos los cambios en la pagina.
# :::
