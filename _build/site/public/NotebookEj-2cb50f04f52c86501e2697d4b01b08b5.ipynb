# %% [markdown]
# # Ejemplo de un Notebook

# %%
from IPython.display import YouTubeVideo

# Reemplaza el ID por el de tu video (lo que sigue después de v=)
YouTubeVideo('NXcXB1lJskA', width=1000, height=400)
