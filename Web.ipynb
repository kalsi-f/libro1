# %% [markdown]
# # 3. Libro en formato web con github pages

# %%
jupyter book init --gh-pages

# %% [markdown]
# :::{tip}
# Recordar que para ir actualizando la web es necesario hacer comit de los cambios y luego hacer un build, asi se actualizara el sitio web
# :::
